# %% [markdown]
# <a href="https://colab.research.google.com/github/Sugan2002/19AI539-Ex.No-1/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# %%
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import tensorflow as tf

# %%
worksheet = gc.open('FirstDataset').sheet1
rows = worksheet.get_all_values()
df = pd.DataFrame(rows[1:], columns=rows[0])
df = df.astype({'X':'float'})
df = df.astype({'Y':'float'})
df.head(n=10)
# Out:
#       X      Y
# 0  10.0   25.0
# 1  20.0   45.0
# 2  30.0   65.0
# 3  40.0   85.0
# 4  50.0  105.0
# 5  60.0  125.0
# 6  70.0  145.0
# 7  80.0  165.0
# 8  90.0  185.0

# %%
df.dtypes
# Out:
# X    float64
# Y    float64
# dtype: object

# %%
df=df.astype({'X':'float'})
df=df.astype({'Y':'float'})

# %%
df.dtypes
# Out:
# X    float64
# Y    float64
# dtype: object

# %%
x=df[['X']].values

# %%
x
# Out:
# array([[10.],
#        [20.],
#        [30.],
#        [40.],
#        [50.],
#        [60.],
#        [70.],
#        [80.],
#        [90.]])

# %%
y=df[['Y']].values

# %%
y
# Out:
# array([[ 25.],
#        [ 45.],
#        [ 65.],
#        [ 85.],
#        [105.],
#        [125.],
#        [145.],
#        [165.],
#        [185.]])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.33,random_state=50)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train.shape
# Out:
# (6, 1)

# %%
X_test.shape
# Out:
# (3, 1)

# %%
X_test
# Out:
# array([[50.],
#        [70.],
#        [80.]])

# %%
X_train
# Out:
# array([[30.],
#        [20.],
#        [60.],
#        [40.],
#        [90.],
#        [10.]])

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled = scaler.transform(X_train)

# %%
X_train_scaled
# Out:
# array([[0.25 ],
#        [0.125],
#        [0.625],
#        [0.375],
#        [1.   ],
#        [0.   ]])

# %%
ai_brain = Sequential([
    Dense(2,activation='relu'),
    Dense(1,activation='relu')
])

# %%
ai_brain.compile(optimizer='rmsprop',loss='mse')

# %%
ai_brain.fit(x=X_train_scaled,y=Y_train,epochs=20000)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 6ms/step - loss: 8740.7871
# Epoch 2169/20000
# 1/1 [==============================] - 0s 12ms/step - loss: 8739.4072
# Epoch 2170/20000
# 1/1 [==============================] - 0s 6ms/step - loss: 8738.0283
# Epoch 2171/20000
# 1/1 [==============================] - 0s 5ms/step - loss: 8736.6475
# Epoch 2172/20000
# 1/1 [==============================] - 0s 6ms/step - loss: 8735.2686
# Epoch 2173/20000
# 1/1 [==============================] - 0s 6ms/step - loss: 8733.8877
# Epoch 2174/20000
# 1/1 [==============================] - 0s 10ms/step - loss: 8732.5068
# Epoch 2175/20000
# 1/1 [==============================] - 0s 10ms/step - loss: 8731.1250
# Epoch 2176/20000
# 1/1 [==============================] - 0s 10ms/step - loss: 8729.7441
# Epoch 2177/20000
# 1/1 [==============================] - 0s 11ms/step - loss: 8728.3613
# Epoch 2178/20000
# ...
